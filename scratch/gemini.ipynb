# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

# %%
from google import genai
client = genai.Client(api_key=api_key)

# %%
model = "gemini-2.5-flash"

# %%
input_str = "where can I find plain text document datasets for field manuals for, say, oil well mining or construction or something like that? the purpose is to acquire a couple of easily parseable documents that I can supply to a RAG system for an LLM PoC project I'm working on. i mainly want image-free documents, ideally in formats like markdown or plain text that are easily readable."

# %%
response2 = client.models.generate_content(model=model, contents=input_str)

# %%
print(response2)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""You're looking for a sweet spot: domain-specific, procedural text that's public domain and easily parsable. While perfectly pre-formatted Markdown/plain text might be a bit of a unicorn for official, lengthy manuals, you can get very close with a little effort, primarily by extracting text from well-structured HTML or PDFs.
#
# Here are the best sources, with tips on how to get the clean text you need:
#
# ---
#
# ### Top Recommendations
#
# 1.  **U.S. Military Field Manuals (FMs, TMs, ATTPs)**
# ...

# %%
print(response.text)
# Out:
# Finding plain text document datasets for field manuals, especially in specialized domains like oil well mining or construction, can be a bit challenging because such documents are often:
# 1.  **Proprietary:** Companies consider their operational manuals trade secrets.
# 2.  **Behind Paywalls:** Industry standards bodies charge for their documents.
# 3.  **PDF-based:** While text *is* in them, extracting clean plain text can require OCR or advanced PDF parsers.
# 4.  **Not "packaged" as datasets:** They exist as individual documents rather than pre-compiled NLP datasets.
#
# However, there are several strategies and sources you can explore:
#
# ### 1. Government and Regulatory Agencies
#
# These are often excellent sources because their documents are typically in the public domain and focus on safety, best practices, and regulations, which are the core of field manuals.
#
# ...
